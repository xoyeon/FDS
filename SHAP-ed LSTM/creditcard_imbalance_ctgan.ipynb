# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action = 'ignore')

# %%
data = pd.read_csv('./dataset/creditcard.csv')
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
print("Number of fraudulent transactions:", data['Class'].sum())
print("Number of normal transactions:", len(data[data['Class']==0]))
sns.countplot(x='Class',data=data)
# Out:
# Number of fraudulent transactions: 492
# Number of normal transactions: 284315
# <AxesSubplot: xlabel='Class', ylabel='count'>

# %%
#Display Pearson correlation HeatMap for all variables
plt.figure(figsize=(30,20))
cor = data.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
# 시간대별 트랜잭션 양
f, (ax1, ax2) = plt.subplots(2,1, sharex=True, figsize=(12,4))
ax1.hist(data.Time[data.Class==1], bins=50)
ax2.hist(data.Time[data.Class==0], bins=50)

ax1.set_title('Fraud')
ax2.set_title('Normal')
plt.xlabel('Time(in Seconds)'); plt.ylabel('Number of Transactions')
plt.show()

# %%
# 금액대별 트랜잭션 양
f, (ax1, ax2) = plt.subplots(2,1, sharex=True, figsize=(12,4))
ax1.hist(data.Amount[data.Class==1], bins=30)
ax2.hist(data.Amount[data.Class==0], bins=30)
ax1.set_title('Fraud')
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.yscale('log')
plt.show()

# %%
# Plotting all the variable in displot to visualise the distribution
var = list(data.columns.values)
# dropping Class columns from the list
var.remove("Class")

i = 0
t0 = data.loc[data['Class'] == 0]
t1 = data.loc[data['Class'] == 1]

plt.figure()
fig, ax = plt.subplots(10,3,figsize=(30,45));

for feature in var:
    i += 1
    plt.subplot(10,3,i)
    sns.kdeplot(t0[feature], bw=0.5,label="0")
    sns.kdeplot(t1[feature], bw=0.5,label="1")
    plt.xlabel(feature, fontsize=12)
    locs, labels = plt.xticks()
    plt.tick_params(axis='both', which='major', labelsize=12)
    plt.grid()
plt.show()

# %% [markdown]
# # CTGAN으로 synthetic data 생성
# https://github.com/sdv-dev/CTGAN

# %%
# from ctgan import CTGAN
# from ctgan import load_demo

# real_data = data[data['Class']==1]

# # Names of the columns that are discrete
# discrete_columns = [
#     'Amount',
#     'Time',
#     'Class'
# ]

# ctgan = CTGAN(epochs=10)
# ctgan.fit(real_data, discrete_columns)

# # Create synthetic data
# synthetic_data = ctgan.sample(283823)

# %%
# synthetic_data

# %%
# new_data = pd.concat([data,synthetic_data]).sort_values(['Time'])
# new_data.head()

# %%
new_data = pd.read_csv("./dataset/new_creditcard.csv")

# %%
print("Number of fraudulent transactions:", new_data['Class'].sum())
print("Number of normal transactions:", len(new_data[new_data['Class']==0]))
sns.countplot(x='Class',data=new_data)
# Out:
# Number of fraudulent transactions: 284315
# Number of normal transactions: 284315
# <AxesSubplot: xlabel='Class', ylabel='count'>

# %%
#Display Pearson correlation HeatMap for all variables
plt.figure(figsize=(30,20))
cor = new_data.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
# 시간대별 트랜잭션 양
f, (ax1, ax2) = plt.subplots(2,1, sharex=True, figsize=(12,4))
ax1.hist(new_data.Time[new_data.Class==1], bins=50)
ax2.hist(new_data.Time[new_data.Class==0], bins=50)

ax1.set_title('Fraud')
ax2.set_title('Normal')
plt.xlabel('Time(in Seconds)'); plt.ylabel('Number of Transactions')
plt.show()

# %%
# 금액대별 트랜잭션 양
f, (ax1, ax2) = plt.subplots(2,1, sharex=True, figsize=(12,4))
ax1.hist(new_data.Amount[new_data.Class==1], bins=30)
ax2.hist(new_data.Amount[new_data.Class==0], bins=30)
ax1.set_title('Fraud')
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.yscale('log')
plt.show()

# %%
# Plotting all the variable in displot to visualise the distribution
var = list(new_data.columns.values)
# dropping Class columns from the list
var.remove("Class")

i = 0
t0 = new_data.loc[new_data['Class'] == 0]
t1 = new_data.loc[new_data['Class'] == 1]

plt.figure()
fig, ax = plt.subplots(10,3,figsize=(30,45));

for feature in var:
    i += 1
    plt.subplot(10,3,i)
    sns.kdeplot(t0[feature], bw=0.5,label="0")
    sns.kdeplot(t1[feature], bw=0.5,label="1")
    plt.xlabel(feature, fontsize=12)
    locs, labels = plt.xticks()
    plt.tick_params(axis='both', which='major', labelsize=12)
    plt.grid()
plt.show()

# %%
sns.scatterplot(x='V17', y='V13', hue='Class', data=data)
# Out:
# <AxesSubplot: xlabel='V17', ylabel='V13'>

# %%
sns.scatterplot(x='V17', y='V13', hue='Class', data=new_data)
# Out:
# <AxesSubplot: xlabel='V17', ylabel='V13'>
