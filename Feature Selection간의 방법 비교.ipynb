# %%
import pandas as pd
import numpy as np

# %%
from pycaret.utils import version
from pycaret.classification import *
version()
# Out:
# '2.3.10'

# %%
data = pd.read_csv('./dataset/inflearn_creditcard.csv')
data.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 0  0:00:00 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1  0:00:00  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2  0:00:24 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3  0:00:24 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4  0:00:48 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9       V10       V11       V12       V13  \
# 0  0.239599  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390
# 1 -0.078803  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095
# 2  0.791461  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293
# 3  0.237609  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757
# 4  0.592941 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852
#
#         V14       V15       V16       V17       V18       V19       V20  \
# ...

# %% [markdown]
# # NON-selected RF

# %%
non = setup(data, target = 'Class', session_id=786)
# Out:
# <style type="text/css">
# #T_b36be_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b36be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b36be_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b36be_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b36be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b36be_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_b36be_row0_col1" class="data row0 col1" >786</td>
#     </tr>
#     <tr>
#       <th id="T_b36be_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b36be_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b36be_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_b36be_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# IntProgress(value=0, description='Processing: ', max=74)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                23:40:42
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
# <style type="text/css">
# #T_ef275 th {
#   text-align: left;
# }
# #T_ef275_row0_col0, #T_ef275_row0_col1, #T_ef275_row0_col2, #T_ef275_row0_col3, #T_ef275_row0_col4, #T_ef275_row0_col5, #T_ef275_row0_col6, #T_ef275_row0_col7, #T_ef275_row0_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_ef275">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef275_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ef275_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ef275_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ef275_level0_col3" class="col_heading level0 col3" >Recall</th>
# ...

# %% [markdown]
# # 통계적 기법으로 feature selected

# %%
df = data[['V16','V14','V12','V9','V8','V4','V11','V10','V7','V28','V26','V21','V17','V13','Time','Amount','Class']]
df.head()

# %%
stat = setup(df, target = 'Class', session_id=786)

# %% [markdown]
# # SHAP feature selected

# %%
df_shap = data[['V1','V2','V3','V4','V7','V9','V10','V11','V12','V14','V16','V17','V18','V19','Amount','Class']]
df_shap.head()

# %%
shaped = setup(df_shap, target = 'Class', session_id=786)
